# %%
import numpy as np
import pandas as pd
import sklearn.preprocessing
import datetime

df = pd.read_csv('data/features_subset.csv')
# Out:
# C:\Users\asealy\AppData\Local\Temp\ipykernel_20880\3139271909.py:6: DtypeWarning: Columns (74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/features_subset.csv')

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %%
df.loc[df['mvel1']>= 1e+02]
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
#          permno       DATE         mvel1      beta    betasq     chmom  \
# 0         10006 1957-01-31   82249.00000  1.122846  1.260784  0.047180
# 1         10014 1957-01-31    3903.37500  0.426734  0.182102 -0.275641
# 2         10022 1957-01-31    9273.25000  1.066449  1.137313 -0.025490
# 3         10030 1957-01-31   54465.87500  0.926038  0.857547  0.018171
# 4         10057 1957-01-31   40250.00000  1.247748  1.556875  0.025785
# ...         ...        ...           ...       ...       ...       ...
# 3713512   89482 2016-07-29  889017.71874  0.880614  0.775481  0.172300
# 3713513   89489 2016-07-29  965940.56520 -0.014792  0.000219  0.022075
# 3713514   89490 2016-07-29  227055.50000  0.044098  0.001945  0.039254
# 3713515   89491 2016-07-29  295623.61347 -0.006217  0.000039  0.060203
# ...
